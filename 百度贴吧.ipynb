# %%
import urllib
import re

# %%
def get_response_urlopen(url):
    response = urllib.request.urlopen(url)
    return response

def get_response_request(url):
    headers = {
            'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13) AppleWebKit/537.36 (KHTML, like Gecko)\
            Chrome/65.0.3325.163 Safari/537.36'
        }
    
    request = urllib.request.Request(url, headers= headers)
    response = get_response_urlopen(request)
    return response

# %%
url = 'http://tieba.baidu.com/f?kw=python&ie=utf-8&pn=0'

def get_content(url):
    res = get_response_request(url)
    content = res.read().decode('utf-8')
    return content

# %%
# content = get_content(url)

# %%
def get_titles(url):
    content = get_content(url)
    pattern = re.compile('<.*?noreferrer.*?title="(.*?)" target="_blank"',re.I)
    titles = re.findall(pattern,content)
    print(len(titles))
    for i in titles:
        print(i)
    return titles
get_titles(url)
# Out:
# 50
# 【本吧广告举报专贴】
# 想用冒泡法进行排序，求问一下大神为什么排序失败呢
# 零基础想学好python，会很辛苦，有不懂可以加群一起来学
# 求大佬指导，为什么找不到指定路径
# 有无大佬帮写python题
# python零基础到项目实战资源免费分享，之前学习的工作了@@
# 编程任务完成不了？来这：
# 编程任务不能完成的，都可以来这里：
# 学pyyhon要是拿出之前的态度早就出师了，学习让我快乐啊😄
# 自学刚刚结束，上个图吧
# 工作一年多了，资料对我也没啥用了，无偿给你们吧
# python学习书籍整理收集
# python好就业吗现在？
# 这个吧都是广告吗，，没一点学习交流的帖子。。
# 大专生自学Python到找到工作的心得
# 悄悄整理的某机构内部编程资料无偿分享给大家，外面不容易买到哦
# 问一下result=result[0]这句话是什么意思，为什
# 求助
# 刚从培训过python的同学里得到全套资料，需要python
# 有人知道这个人用的是什么编辑器吗？
# Python全栈+爬虫资料，找我无偿分享。
# 有要python资料的嘛？免费送了
# 一运行就“synataxerror”...怎么办？求解
# 遇到了个难题，有哪位大佬可以看看Python用面向对象的方法
# da shen qiu jie
# 有编程任务搞不定?可以来这。
# 为什么我这终端不出结果
# python+高德api 租房推荐系统问题咨询
# 【求大神】有没有大神知道这种错误如何处理
# 准备学习python,但是进不去这个问题要怎么解决？谢谢
# 求大神帮忙
# Python Django的课程，我有300多集，有没有人要
# Python书上说：“要配置Geany，请选择菜单Build
# 翻来覆去，还是把整理好的Python资料分享出来
# 蠢新反转算法的迷之bug
# 如何零基础学好Python，力所能及给大家分享
# 请大神赐教！！！！
# 请问大家19行为什么会报错呢，我这个程序是为了求所以鱼的总数
# 请问有人用过pychem包吗
# Python爬虫是什么
# 那么多转行学IT的到底是因为什么
# 从今天开始，自学c，python，go。立帖为证，半年后见分
# 有没有一起学Python的小伙伴？
# 本人大专电子专业在读，请问大学期间学Python对找工作有用
# 新人求助一道题目QAQ
# 求助求助，用原始的http做一个简单的网络爬虫！实现一个简单
# 求问：图里面那个len（）函数，为什么在pycharm里面执
# python turtle绘图实现：
# 小白求助，这个错误是出到哪了？
# 打算学习python，刚买的教程，将近500集视频，太多了，
# ['【本吧广告举报专贴】',
#  '想用冒泡法进行排序，求问一下大神为什么排序失败呢',
#  '零基础想学好python，会很辛苦，有不懂可以加群一起来学',
#  '求大佬指导，为什么找不到指定路径',
#  '有无大佬帮写python题',
#  'python零基础到项目实战资源免费分享，之前学习的工作了@@',
#  '编程任务完成不了？来这：',
#  '编程任务不能完成的，都可以来这里：',
#  '学pyyhon要是拿出之前的态度早就出师了，学习让我快乐啊😄',
#  '自学刚刚结束，上个图吧',
#  '工作一年多了，资料对我也没啥用了，无偿给你们吧',
#  'python学习书籍整理收集',
#  'python好就业吗现在？',
#  '这个吧都是广告吗，，没一点学习交流的帖子。。',
#  '大专生自学Python到找到工作的心得',
#  '悄悄整理的某机构内部编程资料无偿分享给大家，外面不容易买到哦',
#  '问一下result=result[0]这句话是什么意思，为什',
#  '求助',
#  '刚从培训过python的同学里得到全套资料，需要python',
#  '有人知道这个人用的是什么编辑器吗？',
#  'Python全栈+爬虫资料，找我无偿分享。',
#  '有要python资料的嘛？免费送了',
#  '一运行就“synataxerror”...怎么办？求解',
#  '遇到了个难题，有哪位大佬可以看看Python用面向对象的方法',
#  'da shen qiu jie',
#  '有编程任务搞不定?可以来这。',
#  '为什么我这终端不出结果',
#  'python+高德api 租房推荐系统问题咨询',
#  '【求大神】有没有大神知道这种错误如何处理',
#  '准备学习python,但是进不去这个问题要怎么解决？谢谢',
#  '求大神帮忙',
#  'Python Django的课程，我有300多集，有没有人要',
#  'Python书上说：“要配置Geany，请选择菜单Build',
#  '翻来覆去，还是把整理好的Python资料分享出来',
#  '蠢新反转算法的迷之bug',
#  '如何零基础学好Python，力所能及给大家分享',
#  '请大神赐教！！！！',
#  '请问大家19行为什么会报错呢，我这个程序是为了求所以鱼的总数',
#  '请问有人用过pychem包吗',
#  'Python爬虫是什么',
#  '那么多转行学IT的到底是因为什么',
#  '从今天开始，自学c，python，go。立帖为证，半年后见分',
#  '有没有一起学Python的小伙伴？',
#  '本人大专电子专业在读，请问大学期间学Python对找工作有用',
#  '新人求助一道题目QAQ',
#  '求助求助，用原始的http做一个简单的网络爬虫！实现一个简单',
#  '求问：图里面那个len（）函数，为什么在pycharm里面执',
#  'python turtle绘图实现：',
#  '小白求助，这个错误是出到哪了？',
#  '打算学习python，刚买的教程，将近500集视频，太多了，']

# %%
def get_authors(url):
    content = get_content(url)
    pattern = re.compile('主题作者: (.*?)"',re.S)
    authors = re.findall(pattern, content)
    print(authors)
    return authors
    
get_authors(url)
# Out:
# ['异国的猫º', '九九九😂', 'python优秀', '方寸宠物🐶', '-鱼人萨', '嬴政殿下◆◆', '鲟梦春秋', '阿嚏__ok', '鲜血半月', '静默期待悸动', '403810629', '天蝎小魂儿', 'manito666', '24222242554', 'GDSFSDH9', '九九九😂', '天天开心的我的', '求仙拜佛◎', '正规编程代做', '可乐-渴了', 'lpeydb', 'myym405', '正规编程代做', '正规编程代做', '☞GhostΩ', '小猿圈加加', '小猿圈加加', '2amor998', '441202881', '爽朗的南烛', '化鲸▫', '开心好生活趣', 'nnswdx', 'Daisy🌌🌌', '华清创客学院', '旧人的离岛20M', '起风了748', '我是谁😄', '真丶椰子壳壳', '1181729005', '苏苏冰5', 'Lrutcy', '优就业智慧老师', '小小伊姐姐', '伙玉督牙宦', '我吃青椒go', 'zfs8747791', 'heaven祖鸿雪', '大天使♤', '伊卡洛斯的黑翼']

# %%
def get_lastReplyTime(url):
    content = get_content(url)
    pattern = re.compile('reply_data.*?>(.*?)</',re.S)
    replyTime = re.findall(pattern, content)
    for i in replyTime:
        print(i.strip())
    return replyTime
    
get_lastReplyTime(url)
# Out:
# 16:23
# 17:09
# 16:30
# 16:19
# 16:18
# 17:02
# 16:59
# 17:08
# 15:55
# 15:42
# 15:07
# 15:22
# 14:45
# 14:44
# 16:37
# 14:40
# 14:36
# 16:40
# 14:29
# 14:26
# 16:43
# 16:33
# 14:04
# 14:03
# 13:53
# 13:40
# 13:26
# 13:24
# 13:11
# 13:03
# 11:42
# 11:54
# 11:36
# 11:17
# 10:56
# 10:34
# 10:18
# 10:09
# 10:23
# 10:22
# 01:34
# 6-30
# 09:34
# 09:37
# 09:07
# 09:19
# 08:54
# 08:52
# 08:42
# ['\r\n            16:23        ',
#  '\r\n            17:09        ',
#  '\r\n            16:30        ',
#  '\r\n            16:19        ',
#  '\r\n            16:18        ',
#  '\r\n            17:02        ',
#  '\r\n            16:59        ',
#  '\r\n            17:08        ',
#  '\r\n            15:55        ',
#  '\r\n            15:42        ',
#  '\r\n            15:07        ',
#  '\r\n            15:22        ',
#  '\r\n            14:45        ',
#  '\r\n            14:44        ',
#  '\r\n            16:37        ',
#  '\r\n            14:40        ',
#  '\r\n            14:36        ',
#  '\r\n            16:40        ',
#  '\r\n            14:29        ',
#  '\r\n            14:26        ',
#  '\r\n            16:43        ',
#  '\r\n            16:33        ',
#  '\r\n            14:04        ',
#  '\r\n            14:03        ',
#  '\r\n            13:53        ',
#  '\r\n            13:40        ',
#  '\r\n            13:26        ',
#  '\r\n            13:24        ',
#  '\r\n            13:11        ',
#  '\r\n            13:03        ',
#  '\r\n            11:42        ',
#  '\r\n            11:54        ',
#  '\r\n            11:36        ',
#  '\r\n            11:17        ',
#  '\r\n            10:56        ',
#  '\r\n            10:34        ',
#  '\r\n            10:18        ',
#  '\r\n            10:09        ',
#  '\r\n            10:23        ',
#  '\r\n            10:22        ',
#  '\r\n            01:34        ',
#  '\r\n            6-30        ',
#  '\r\n            09:34        ',
#  '\r\n            09:37        ',
#  '\r\n            09:07        ',
#  '\r\n            09:19        ',
#  '\r\n            08:54        ',
#  '\r\n            08:52        ',
#  '\r\n            08:42        ']

# %%
def get_replyContent(url):
    content = get_content(url)
    pattern = re.compile('threadlist_abs_onlyline ">(.*?)</div',re.S)
    replyContent = re.findall(pattern, content)
    l = 1
    for i in replyContent:
        print(l, i.strip())
        l+=1
#     print(replyContent)
    
get_replyContent(url)
# Out:
# 1 想用冒泡法进行排序，求问一下大神为什么排序失败呢
# 2 因为目前python非常火，应用非常的广泛，是目前最火的行业之一，竞争很大，工资很高，未来发展也极好。 首先告诉你的是，零基础学习Python 难度还是有的，Python的专业程度本身就不简单，学习这事本来就是一件非常煎熬的事情，人都不愿意学习，可是没办法，为了生存掌握一个技能，你必须学，如果你认真的对待，你就找不到高薪水的工作，所以首先学习Python意志，坚持非常重要，很多人放弃的原因根本就是缺乏这些素质。 我个人建议：如条件还
# 3 rt
# 4 有无大佬帮写python题
# 5 主要是python零基础 web全栈开发和爬虫方向的 觉得有帮助的楼下
# 6
# 7
# 8 学pyyhon要是拿出之前的态度早就出师了，学习让我快乐啊😄
# 9 第一阶段：Python入门；第二阶段：Python 深入与提高；第三阶段：Python 网络与并发编程；第五阶段：Linux 环境编程基础；第六阶段：Python 核心特性；第七阶段：网页编程基础；第八阶段：Python_Django 框架；第九阶段：Python_Tornado 框架；第十阶段：Python_大型电商项目；第十一阶段：Python 爬虫开发；第十二阶段：面试和成功求职的秘技；第十三阶段：入职后快速成长到CTO。
# 10 Python基础，Python全践开发，爬虫，想这个方向发展的，无偿给你们了
# 11 一份收集的python学习电子资料分享给大家
# 12 刚来深圳 想认真找份工作IT类的工作 但是基本上没有什么技术 想先学一下 大家是自学的还是在去机构培训的啊？
# 13
# 14 先做个自我介绍，我13年考上一所很烂专科民办的学校，学的是生物专业，具体的学校名称我就不说出来献丑了。13年我就辍学了，我在那样的学校，一年学费要1万多，但是根本没有人学习，我实在看不到希望，我就退学了。 退学后我也迷茫，大专都没有毕业，我真的不知道我能干什么，我在纠结着我能做什么。所以辍学后我一段时间，我想去找工作，因为我比较沉默寡言，不是很会说话，我不适合去应聘做业务。我想应聘做技术的，可是处处碰壁。
# 15 悄悄整理的某机构内部编程资料无偿分享给大家，外面不容易买到哦
# 16 问一下result=result[0]这句话是什么意思，为什么不写会出错
# 17 初学python有些不懂，这个该怎么改
# 18 刚从培训过python的同学里得到全套资料，需要python全套资料的私我（避免说是打广告），一起共同学习
# 19 看新闻时发这个人的编辑器很有意思，尤其是列高亮好像很好玩，看着不像是PyCharm或Visual Studio Code
# 20
# 21
# 22
# 23 遇到了个难题，有哪位大佬可以看看 Python用面向对象的方法编写计算器
# 24
# 25 有编程任务搞不定?可以来这。
# 26 为什么我这终端不出结果
# 27 先用python写爬取租房网的信息生产 存储信息的 csv文件 然后用接高德api 创建一个网页 index.html 将csv数据导入进去 变成一个可以在地图上操作的租房推荐系统。 不过这个实验有很多问题，希望在这里能找到解答。
# 28
# 29 准备学习python,但是进不去 这个问题要怎么解决？谢谢
# 30 怎么在Python中实现弹窗，让用户选择“是”或“否”，然后执行下一步？
# 31 Python Django的课程，我有300多集，有没有人要。
# 32 Python书上说：“要配置Geany，请选择菜单Build&gt;Set Build Commands” 为什么找不到在哪里
# 33 翻来覆去，还是把整理好的Python资料分享出来
# 34 如题，一脸懵逼
# 35 因为目前web前端非常火，应用非常的广泛，是目前最火的行业之一，竞争很大，工资很高，未来发展也极好。 首先告诉你的是，零基础学习开始学习web前端肯定难，web前端的专业程度本身就不简单，学习这事本来就是一件非常煎熬的事情，人都不愿意学习，可是没办法，为了生存掌握一个技能，你必须学，如果你认真的对待，你就找不到高薪水的工作，所以首先学习web前端意志，坚持非常重要，很多人放弃的原因根本就是缺乏这些素质。
# 36 请问大家，python如何将运行结果传递给另一个python，只要结果就行
# 37 请问大家19行为什么会报错呢，我这个程序是为了求所以鱼的总数和金额，中间的操作是对鱼的数量与金额的修改
# 38 请问有人用过pychem包吗
# 39
# 40
# 41 从今天开始，自学c，python，go。立帖为证，半年后见分晓。
# 42 一个南方的姑娘，计算机毕业，工作一年了，因为工作需要所以打算学习Python，有没有小伙伴一起学习的？
# 43 本人大专电子专业在读，请问大学期间学Python对找工作有用吗？
# 44 大概功能就是判断输入内容。 给了已经输过的字母list然后判断输入的是不是一个字母。 如果不是一个字母或者是在已经输过的list中就返回那句 'You need to enter one alphabetic character which you haven\'t already guessed. Try again' 如果是大写没输入过的字母就自动改成小写加入到list中再返回这个字母。 如果是小写没输入过的字母就加到list再返回这个字母。 我写的是这个有什么问题QAQ while循环刚学还不太会这个返回一直是需要重新输入QAQ 求大神帮忙看一下谢谢！
# 45 求助求助，用原始的http做一个简单的网络爬虫！ 实现一个简单的http客户端程序，能够自动的通过用户输入的关键字来抓取网页。
# 46 求问：图里面那个len（）函数，为什么在pycharm里面执行无结果?但还是显示执行了。而且不知道点了什么，只要是括号里先按一下单引号，再输abcd就会变成莫名其妙的带尾巴的abcd！类似这样：（ç），这都什么鬼
# 47
# 48 小白求助，这个错误是出到哪了？
# 49 打算学习python，刚买的教程，将近500集视频，太多了，立贴为证，我要发奋图强！！！有想一起学习的大家可以交流下。

# %%
def get_lastPage(url):
    content = get_content(url)
    pattern = re.compile('<a href.*?pn=(.*?)".*?last')
    last = re.findall(pattern, content)
    print(last)

# %%
 '''
批量爬取百度贴吧页面数据
先写一个main,提示用户输入贴吧地址

'''
import urllib
import re

def get_response_urlopen(url):
    response = urllib.request.urlopen(url)
    return response


def get_response_request(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13) AppleWebKit/537.36 (KHTML, like Gecko)\
            Chrome/65.0.3325.163 Safari/537.36'
    }

    request = urllib.request.Request(url, headers=headers)
    response = get_response_urlopen(request)
    print(response.read().decode('utf-8'))
    return response

def get_content(url):
    res = get_response_request(url)
    content = res.read().decode('utf-8')
    return content

def get_titles(url):
    content = get_content(url)
    pattern = re.compile('<.*?noreferrer.*?title="(.*?)" target="_blank"',re.I)
    titles = re.findall(pattern,content)
    print(len(titles))
    for i in titles:
        print(i)
    return titles


def tiebaSpider():
    kw = input('输入贴吧名字: ')
    beginPage = int(input('请输入起始页: '))
    endPage = int(input('请输入截止页: '))
    url = 'http://tieba.baidu.com/f?'
    kw = urllib.parse.urlencode({'kw':kw})
    url = url + kw + '&ie=utf-8&pn='

    for i in range(beginPage, endPage + 1):
        newurl = url + str((i-1)*50)
        get_titles(newurl)

if __name__ == '__main__':
    tiebaSpider()
