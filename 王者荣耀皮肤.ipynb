# %%
import urllib
import re

# %%
def get_response_urlopen(url):
    response = urllib.request.urlopen(url)
    return response

def get_response_request(url):
    headers = {
            'User-Agent' : 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13) AppleWebKit/537.36 (KHTML, like Gecko)\
            Chrome/65.0.3325.163 Safari/537.36'
        }
    
    request = urllib.request.Request(url, headers= headers)
    response = get_response_urlopen(request)
    return response

# %%
url = 'https://pvp.qq.com/web201605/wallpaper.shtml###'

def get_content(url):
    res = get_response_request(url)
    content = res.read().decode('gbk')
    return content
c = get_content(url)
print(c)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="gbk">
# <meta name="author" content="Tencent-CP">
# <meta http-equiv="x-ua-compatible" content="IE=edge">
# <meta name="Copyright" content="Tencent">
# <meta name="keywords" content="王者荣耀官方为玩家提供王者荣耀高清无水印壁纸下载，新英雄新皮肤高清壁纸下载">
# <meta name="description" content="王者荣耀壁纸下载,王者荣耀图片下载,王者荣耀手机壁纸下载,王者荣耀高清壁纸下载">
# <title>王者荣耀壁纸下载-王者荣耀官方网站-腾讯游戏</title>
# <link href="//game.gtimg.cn/images/yxzj/web201706/css/comm-v1.css" rel="stylesheet" />
# <link rel="stylesheet" type="text/css" href="css/paperlist.css">
# <!--<script>
#   var setSite={
#     siteType:"os",	       //必填项:"os"代表是官网，如果不是，则填写actName比如a20160701xxx
#     pageType:"wallpaperList",    //必填项:本页面的定位；比如 index|| main || list || newsList || detail || newsDetail
#     pageName:"壁纸列表页"    //必填项:本页面的定位；比如 首页|| 主页|| 列表页 || 新闻列表页 || 详情页 || 新闻详情页
#   }
#
#  </script>-->
# </head>
#
# <body class="old-header">
# <div id="header" class="header tganime-header-fix">
#     <div class="header-inner">
#         <h1><a href="//pvp.qq.com/" class="logo pa" title="王者荣耀" onclick="PTTSendClick('headNav','logo','logo');">王者荣耀</a></h1>
#         <!--=========主导航==========-->
# 		<ul class="main-nav clearfix">
# 			<li class="first-nav"> <a href="//pvp.qq.com/" target="_blank" title="官网首页" onclick="PTTSendClick('headNav','home','官网首页');">官网首页<em>HOME</em></a> </li>
# 			<li> <a href="/web201605/herolist.shtml" target="_blank" title="游戏资料" onclick="PTTSendClick('headNav','data','游戏资料');">游戏资料<em>DATA</em></a> </li>
# 			<li> <a href="/raiders/" target="_blank" title="内容中心" onclick="PTTSendClick('headNav','strategy','内容中心');">内容中心<em>CONTENTS</em></a> </li>
# 			<li> <a href="/match/kpl/index.shtml" target="_blank" title="赛事中心" onclick="PTTSendClick('headNav','match','赛事中心');">赛事中心<em>MATCH</em></a> </li>
# 			<li> <a href="/cp/a20171023pvppc/" target="_blank" title="商城/合作" onclick="PTTSendClick('headNav','CULTURE','百态王者');">百态王者<em>CULTURE</em></a> </li>
# 			<li> <a href="javascript:void(0)" title="社区互动" onclick="PTTSendClick('headNav','Community','社区互动');">社区互动<em>COMMUNITY</em></a> </li>
# 			<li> <a href="javascript:void(0)" target="_blank" title="玩家支持" onclick="PTTSendClick('headNav','player','玩家支持');">玩家支持<em>PLAYER</em></a> </li>
# 		</ul>
#     </div>
#     <!--=====二级导航=====-->
#     <div id="J_subNav" class="sub-nav" style="visibility: hidden;">
#         <ul class="sub-nav-inner">
#         	<li class="down-nav"> &nbsp; </li>
#         	<li class="down-nav"> <a href="/cp/a20170829bbgxsm/index.html" target="_blank" title="版本介绍" onclick="PTTSendClick('headNav','data_ver','版本介绍');">版本介绍</a> <a href="/web201605/introduce.shtml" target="_blank" title="游戏介绍" onclick="PTTSendClick('headNav','data_moba','游戏介绍');">游戏介绍</a> <a href="/web201605/herolist.shtml" target="_blank" title="英雄资料" onclick="PTTSendClick('headNav','data_hero','英雄资料');">英雄资料</a> <a href="/coming/v2/" target="_blank" title="爆料站" onclick="PTTSendClick('headNav','data_coming','爆料站');">爆料站</a> <a href="javascript:void(0)" title="故事站" onclick="TGDialogS('story');PTTSendClick('headNav','data_story','故事站');">故事站</a> <a href="/web201605/wallpaper.shtml" target="_blank" title="游戏壁纸" onclick="PTTSendClick('headNav','data_wallpaper','游戏壁纸');">游戏壁纸</a> </li>
#         	<li class="down-nav"> <a href="/raiders/" target="_blank" title="攻略中心" onclick="PTTSendClick('headNav','strategy_center','攻略中心');">攻略中心</a> <a href="/strategy/" target="_blank" title="英雄攻略" onclick="PTTSendClick('headNav','strategy_hero','英雄攻略');">英雄攻略</a> <a href="/v/" target="_blank" title="视频中心" onclick="PTTSendClick('headNav','strategy_video','视频中心');">视频中心</a> <a href="/author/" target="_blank" title="作者入驻" onclick="PTTSendClick('headNav','author','作者入驻');"><i class="icon-fans"></i>作者入驻</a> <a href="/mcn/" target="_blank" title="媒体入驻" onclick="PTTSendClick('headNav','mcn','媒体入驻');"><i class="icon-fans"></i>媒体入驻</a> </li>
#         	<li class="down-nav"> <a href="/match/kcc.shtml" target="_blank" title="冠军杯" onclick="PTTSendClick('headNav','match_kcc','kcc');">冠军杯</a> <a href="/match/kpl/index.shtml" target="_blank" title="KPL职业联赛" onclick="PTTSendClick('headNav','match_KPL','KPL');">KPL</a> <a href="//pvp.qq.com/cp/a20170818school/index.shtml" target="_blank" title="王者高校联赛" onclick="PTTSendClick('headNav','match_gaoxiao','王者高校联赛');">高校赛</a> <a href="/cp/a20170808city/index.shtml" target="_blank" title="KOC王者城市赛" onclick="PTTSendClick('headNav','match_KOC','KOC');">城市赛</a> <a href="/match/quanmin/index.html#/" target="_blank" title="全民赛" onclick="PTTSendClick('headNav','match_KCC','quanmin');">全民赛</a> </li>
#         	<li class="down-nav"> <a href="/history/" target="_blank" title="王者文化站" onclick="PTTSendClick('headNav','history','王者文化站');">王者文化站</a> <a href="/cp/a20180327music/index.html" target="_blank" title="王者音乐听" onclick="PTTSendClick('headNav','a20180327music','王者音乐听');"><i class="icon-fans"></i>王者音乐听</a> <a href="/wonder/" target="_blank" title="万千世界" onclick="PTTSendClick('headNav','wonder','万千世界');">万千世界</a> <a href="/cp/a20171023pvppc/" target="_blank" title="百态王者" onclick="PTTSendClick('headNav','a20171023pvppc','百态王者');">百态王者</a> <a href="/cp/a20170707zhhz" target="_blank" title="王者信用卡" onclick="PTTSendClick('headNav','life_Credit','王者信用卡');">王者信用卡</a> </li>
#         	<li class="down-nav"> <a href="javascript:void(0)" title="官方助手" onclick="TGDialogS('zhushou');PTTSendClick('headNav','Community_tools','官方助手');"><i class="icon-hot"></i>官方助手</a> <a href="//buluo.qq.com/p/barindex.html?bid=227061" target="_blank" title="手Q部落" onclick="PTTSendClick('headNav','Community_qq','手Q部落');">手Q部落</a> <a href="javascript:void(0)" target="_blank" title="微信圈子" onclick="TGDialogS('weiquan');PTTSendClick('headNav','Community_wx','微信圈子');">微信圈子</a> <a href="//weibo.com/heromoba" target="_blank" title="官方微博" onclick="PTTSendClick('headNav','Community_wb','官方微博');">官方微博</a> <a href="javascript:void(0)" title="微信公众号" onclick="TGDialogS('weixin');PTTSendClick('headNav','Community_wxgzh','微信公众号');">微信公众号</a> <a href="javascript:void(0)" title="手Q订阅号" onclick="TGDialogS('qq');PTTSendClick('headNav','Community_qqdyh','手Q订阅号');">手Q订阅号</a> <a href="/fans/index.shtml" target="_blank" title="同人社区" onclick="PTTSendClick('headNav','Community_fans','同人社区');" class="down-nav-fans"><i class="icon-fans"></i>同人社区</a> </li>
#         	<li class="down-nav"> <a href="//jiazhang.qq.com/jz/home.html " target="_blank" title="成长守护平台" onclick="PTTSendClick('headNav','player_watch','成长守护平台');"><i class="icon-guard"></i>成长守护平台</a> <a href="/cp/a20170726hsbbspc/index.html" target="_blank" title="健康系统" onclick="PTTSendClick('headNav','player_healthy','健康系统');"><i class="icon-health"></i>健康系统</a> <a href="javascript:void(0)" target="_blank" title="客服专区" onclick="TGDialogS('kefu');PTTSendClick('headNav','player_kf','客服专区');">客服专区</a> <a href="/webplat/info/news_version3/15592/24091/24092/24095/m15241/201508/370256.shtml" title="礼包兑换" onclick="PTTSendClick('headNav','player_feedback','礼包兑换');" target="_blank">礼包兑换</a> <a href="//tool.helper.qq.com/v3/wzry/official_website/index.html" title="自助服务" onclick="PTTSendClick('headNav','player_service','自助服务');" target="_blank">自助服务</a> </li>
#         </ul>
#     </div>
# </div>
# <div class="wrapper">
# <div class="zkcontent">
# <div class="paperlistcontent clearfix">
# 	<div class="con1-pos">
#         <i class="tb1 icon fl"></i>
#         <a href="//pvp.qq.com/" target="_blank" title="王者荣耀首页">王者荣耀首页</a>
#         <span>></span>
#         <label>游戏壁纸</label>
#     </div>
# 	<!--壁纸列表（左）-->
# 	<div class="p_listmain_l">
# 		<div class="p_newhero">
# 			<p class="p_newheor_title">
# 			   <img width="17" height="24" src="//game.gtimg.cn/images/yxzj/web201605/page/icon_hero.png" alt="新英雄">
# 			   <span>新英雄新皮肤</span>
# 			</p>
# 			<div id="Work_List_Container_267733_1"></div>
# 			<!-- <div class="p_newhero_item">
# 					<a href="#"><a href="#"><img src="//game.gtimg.cn/images/yxzj/web201605/page/item_img.png" width="220" height="123"  alt="新英雄img"></a></a>
# 					<div class="p_item_imghover">
# 					 <a href="#"><img width="78" height="46"  src="//game.gtimg.cn/images/yxzj/web201605/page/icon_imgzoom.png" alt=""></a>
# 					</div>
# 					<ul>
# 					  <li>武则天武则天武则天武则天武则天武则天武则天武则天武则天武则天</li>
# 					    <li><a href="#"><span>1024x768</span></a><a href="#"><span>1440x900</span></a><a href="#"><span>1920x1200</span></a></li>
# 					</ul>
# 			</div> -->
# 		</div>
# 		<!--高清壁纸-->
# 		<div class="p_hd">
# 			<div class="p_hd_title">
# 			   <img width="25" height="22" src="//game.gtimg.cn/images/yxzj/web201605/page/icon_HD.png" alt="高清壁纸">
# 			   <span>高清壁纸</span>
# 			   <div class="p_hd_titler">
# 			   		<div class="p_sortby p_hd_sortbytime"><a href="javascript:WorkListOrder(0);" class="p_hd_title_bytimetxt">时间排序</a></div>
# 			   		<div class="p_sortby p_hd_sortbyhot"><a href="javascript:WorkListOrder(1);" class="p_hd_title_byhottxt">热度排序</a></div>
#
# 			   		<div class="p_hd_searchbox">
# 						<input id="SearchValue_267733" name="SearchValue" type="text" class="p_hd_searchval" placeholder="请输入壁纸名称搜索">
# 						<a href="javascript:void(0);" class="p_hd_searchicon"><img width="18" height="17" src="//game.gtimg.cn/images/yxzj/web201605/page/vl_search_icon.png"></a>
# 					</div>
# 					<select id="SearchKey_267733" name="SearchKey" style="display:none">
# 					  <option value="">请选择查询关键字</option>
# 					  <option value="sProdName" selected>作品名称</option>
# 					</select>
# 			   </div>
# 			</div>
# 			<div id="Work_List_Container_267733" class="clearfix">
# 				<!-- <div class="p_newhero_item">
# 					<a href="#"><a href="#"><img src="//game.gtimg.cn/images/yxzj/web201605/page/item_img.png" width="220" height="123"  alt="新英雄img"></a></a>
# 					<div class="p_item_imghover">
# 					 <a href="#"><img width="78" height="46"  src="//game.gtimg.cn/images/yxzj/web201605/page/icon_imgzoom.png" alt=""></a>
# 					</div>
# 					<ul>
# 					  <li>武则天武则天武则天武则天武则天武则天武则天武则天武则天武则天</li>
# 					    <li><a href="#"><span>1024x768</span></a><a href="#"><span>1440x900</span></a><a href="#"><span>1920x1200</span></a></li>
# 					</ul>
# 				</div> -->
#
# 			</div>
#
#
# 			<!--分页-->
# 			 <div id="Page_Container_267733" class="pagingPanel">
# 			 	<!-- <ul>
# 			 	  <li><img width="7" height="12" src="//game.gtimg.cn/images/yxzj/web201605/page/cuor_l.png" alt=""></li>
# 			 	   <li>1</li>
# 			 	    <li>2</li>
# 			 	     <li>跳转到</li>
# 			 	      <li>99</li>
# 			 	      <li><img width="7" height="12" src="//game.gtimg.cn/images/yxzj/web201605/page/cuor_r.png" alt=""></li>
# 			 	</ul> -->
# 			 </div>
# 		</div>
# 	</div>
#
# <!--右侧广告栏-->
# <div class="art_r_model">
#   <div class="art_r_downbtnimg" onclick="TGDialogS('download');pgvSendClick({hottag:'main.rightbar.download'});">
#     <img width="195" height="150" src="//game.gtimg.cn/images/yxzj/web201605/page/down_btn.png">
#   </div>
#   <div class="art_r_downcode">
#     <img width="150" height="250" src="//game.gtimg.cn/images/yxzj/web201605/page/down_code.png">
#   </div>
#   <ul class="art_r_title">
#     <li><a href="https://weibo.com/heromoba?is_hot=1" target="_blank">官方微博</a></li>
#     <li class="right-wx"><a href="//bbs.g.qq.com/forum.php?mod=forumdisplay&fid=56891&ADTAG=game.web.yxzj"
#         target="_blank">微信公众号</a>
#       <div class="down-pic">
#         <img src="//game.gtimg.cn/images/yxzj/web201706/images/comm/floatwindow/gzh_code.jpg" alt="微信公众号" width="101"
#           height="100" class="assCode">
#         <p>扫码<span>关注官方公众号</span><br>获取<span>最新资讯及好礼</span></p>
#       </div>
#     </li>
#   </ul>
#   <ul class="art_r_items">
#     <li>
#       <a href="//pvp.qq.com/web201605/introduce.shtml" target="_blank">
#         <span class="art_r_item_icon"><img width="17" height="24"
#             src="//game.gtimg.cn/images/yxzj/web201605/page/icon_nes.png"></span>
#         <span class="art_r_item_word">新手入门</span>
#       </a>
#     </li>
#     <li>
#       <a href="//pvp.qq.com/cp/a20161115tyf/index.shtml" target="_blank">
#         <span class="art_r_item_icon"><img width="26" height="35"
#             src="//game.gtimg.cn/images/yxzj/web201605/page/icon_tiyan.png"></span>
#         <span class="art_r_item_word">体验服</span>
#       </a>
#     </li>
#   </ul>
#   <div class="art_r_bottomImg">
#     <a href='#' data-TGAD='15191,16700' onclick="pgvSendClick({hottag:'page.rightBar.ad'});"></a>
#   </div>
# </div>
# </div>
#
# </div>
# </div>
#
# <!--下载壁纸弹窗-->
# <div id="paper_downalertBoxs" class="paper_downalertBoxs" style="display:none">
# 		<div class="paper_downimg">
# 			<div class="paper_downbanner">
# 				<img id="paper_downalertImgs" width="800" height="600" src="" alt="壁纸"/>
# 			   	<i id="paper_prev" class="cur cl"><img width="27" height="27" src="//game.gtimg.cn/images/yxzj/web201605/page/cl.png"/></i>
# 			    <i id="paper_next" class="cur cr"><img width="27" height="27" src="//game.gtimg.cn/images/yxzj/web201605/page/cr.png"/></i>
# 			    <i id="paper_curname" class="curname">壁纸名称</i>
# 			</div>
# 			<div id="paper_desc" class="paper_downdesc"><ul></ul></div>
# 		</div>
# 		<a href="javascript:closePaper()" class="paper_alertclose">X</a>
# </div>
#
# <!-- Lib  -->
# <script src="//game.gtimg.cn/images/js/jquery/jquery-1.11.3.min.js"></script>
# <script src="//game.gtimg.cn/images/yxzj/web201706/js/lazyload.min.js"></script>
# <script src="//game.gtimg.cn/images/js/milo/milo.js"></script>
# <!-- Site header footer  -->
# <!-- <script src="ossweb-img/js/header.js"></script> -->
# <script src="//game.gtimg.cn/images/yxzj/web201706/js/header.js"></script>
# <script src="//game.gtimg.cn/images/yxzj/web201706/js/footer.js"></script>
# <script src="//game.gtimg.cn/images/js/title.js"></script>
# <!-- AMS KV Link -->
# <div id="kvLinkSetDiv" style="display:none">
# <div class="kv-bg" style="background-image:url(//ossweb-img.qq.com/upload/webplat/info/yxzj/20190704/17387102732315.jpg);">
# 	        		<a href="https://pvp.qq.com/coming/v2/skins/0704-ynql.shtml?ADTAG=pvp.index.kvbtn" onClick="PTTSendClick('btn','topkv','进入专题');"  class="kv_link" title="查看详情" target="_blank">查看详情</a>
#         </div>
#
# </div>
# <!-- Page js -->
# <!-- 统计代码 -->
# <script src="//game.gtimg.cn/images/js/PTT/ping_tcss_tgideas_https_min.js"></script>
# <script type="text/javascript">
# var setSite={   //设置网站属性
#     siteType:"os",
#     pageType:"wallpaper",   //必填项:本页面的定位；按照页面含义填写例如main||list||detail||download||share||page1||pageN
#     pageName:"游戏壁纸-PC",  //必填项:页面中文名
#     osact:0,    //选填项:是否是官网专题(在官网运营的专题)boolean；默认是0；可以在链接上加入参数osact=1来灵活设置
#     ingame:0,   //选填项:是否投放在游戏APP内boolean；默认是0；可以在链接上加入参数ingame=1来灵活设置
#     stayTime:1  //选填项:是否需要统计停留时长boolean；默认是1
# }
# if(typeof(pgvMain)=='function')pgvMain();
# </script>
#
#
# <script type="text/javascript" src="//ossweb-img.qq.com/images/ams/atm/reporting.js?action=51991"></script>
# <script type="text/javascript">
# $(function(){
# 	$('.p_newhero_item ul li span').eq(0).addClass('spanItemClass');
# 	$('.p_newhero_item ul li span').on('click',function() {
# 			$('.p_newhero_item ul li span').removeClass('spanItemClass');
# 			$(this).addClass('spanItemClass');
# 	});
# 	$('.p_hd .p_newhero_item ul li span').eq(0).addClass('spanItemClass');
# 	$('.p_hd .p_newhero_item ul li span').on('click',function() {
# 			$('.p_hd .p_newhero_item ul li span').removeClass('spanItemClass');
# 			$(this).addClass('spanItemClass');
# 	});
# 	$('.pagingPanel ul li').eq(1).addClass('paging');
# 		$('.pagingPanel ul li').on("click",function () {
# 			$('.pagingPanel ul li').removeClass('paging');
# 				$(this).addClass('paging');
# 	});
# 	$('.p_sortby').eq(1).find('a').addClass('sortActive');
# 	$('.p_sortby').on('click',function(){
# 		$('.p_sortby').find('a').removeClass('sortActive');
# 		$(this).find('a').addClass('sortActive');
# 	});
# 	$('.p_item_imghover').on('click',function(){
# 		$('.paper_downalertBoxs').show();
# 	});
# 	$('.paper_alertclose').on('click',function(){
# 		$('.paper_downalertBoxs').hide();
# 	})
#
# });
#
# // 壁纸 - AMS新版爱秀系统 - by jasminjiang 2016年6月13日 19:02:28
#
# sFillTpl = '<div class="p_newhero_item">';
# sFillTpl += '<img data-src="#sThumbURL#" src="" width="215" height="120"  alt="#sProdName#">';
# sFillTpl += '<a href="###" class="p_item_imghover"><span></span></a>';
# sFillTpl += '<h4><a href="###">#sProdName#</a></h4>';
# sFillTpl += '<ul>';
# sFillTpl += '<li class="sProdImgDown sProdImgL2"><a href="###" rel="#sProdImgNo_2#" target="_blank"><span>1024x768</span></a></li>';
# sFillTpl += '<li class="sProdImgDown sProdImgL3"><a href="###" rel="#sProdImgNo_3#" target="_blank"><span>1280x720</span></a></li>';
# sFillTpl += '<li class="sProdImgDown sProdImgL4"><a href="###" rel="#sProdImgNo_4#" target="_blank"><span>1280x1024</span></a></li>';
# sFillTpl += '<li class="sProdImgDown sProdImgL5"><a href="###" rel="#sProdImgNo_5#" target="_blank"><span>1440x900</span></a></li>';
# sFillTpl += '<li class="sProdImgDown sProdImgL6"><a href="###" rel="#sProdImgNo_6#" target="_blank"><span>1920x1080</span></a></li>';
# sFillTpl += '<li class="sProdImgDown sProdImgL7"><a href="###" rel="#sProdImgNo_7#" target="_blank"><span>1920x1200</span></a></li>';
# sFillTpl += '<li class="sProdImgDown sProdImgL8"><a href="###" rel="#sProdImgNo_8#" target="_blank"><span>1920x1440</span></a></li>';
# sFillTpl += '</ul>';
# sFillTpl += '</div>';
#
# var amsCfg_267733 = {
# 	"iAMSActivityId" : "51991", // AMS活动号
# 	"activityId" : "2735",
# 	"sVerifyCode" : "ABCD",
# 	"sDataType" : "JSON",
# 	"_everyRead" : true,
# 	"iListNum" : 4,
# 	"iTypeId" : 1,
# 	//"iStatus" : 0,
# 	"iOrder" : 0,//排序方式 0:时间倒序 1:人气倒序 11:下载数排序
# 	"page" : 0,
# 	"iAreaId" : 0,
# 	"iUin" : 0,
# 	"iGender" : 0,//性别：1:男2:女
# 	"iRoleSex" : 0,//性别：1:男2:女
# 	"sNickName" : '',//encodeURIComponent编码
# 	"sProdName" : '',//encodeURIComponent编码
# 	"SearchKey" : '',
# 	"SearchValue" : '',//encodeURIComponent编码
# 	"iSortNumClose" : 1,
# 	"sListDomId" : "Work_List_Container_267733_1",
# 	"sFillTpl" : sFillTpl,
# 	"sPageDomId" : ["Page_Container_267733"],
# 	"iPageType" : 2, //1:普通分页 2:十页分页模式
# 	"callback" : function(){WorkListClearness()}
# };
#
# milo.ready(function(){
# 	amsInit(51991,267733);
# 	// console.log(amsCfg_267733.sNickName);
# });
# //写入弹出层
# function WriteDialog(thisCont){
# 	var childs = $(".sProdImgL2 a"),
# 		Surl = thisCont.find(childs).attr("rel"),
# 		thisName = thisCont.find("img").attr("alt"),
# 		vid ='',
# 		bigLink = $("#paper_desc ul");
# 		Surl = Surl.replace("jpg/200","jpg/0");
# 		Surl = Surl.replace("thumb_","");
# 		/*if(Surl.indexOf("thumb_") > 0 ){
# 			Surl.replace("thumb_","");
# 		}
# 		else if(Surl.indexOf(".jpg/200") > 0 ){
# 			Surl.replace(".jpg/200",".jpg/0");
# 		}*/
# 	$("#paper_downalertImgs").attr("src",Surl);
# 	$("#paper_curname").html(thisName);
# 	bigLink.html(thisCont.find("ul").html());
# }
# //打开弹层
# function showPaper(thisCont){
# 	need("biz.dialog",function(Dialog){
# 		Dialog.show({id:'paper_downalertBoxs',bgcolor:'#000'});
# 	});
# 	WriteDialog(thisCont);
#
# 	var passCont = thisCont;
# 	$("#paper_prev").click(function(){
# 		if(passCont.prev().length>0){
# 			passCont = passCont.prev();
# 			WriteDialog(passCont);
# 		}
# 	});
# 	$("#paper_next").click(function(){
# 		if(passCont.next().length>0){
# 			passCont = passCont.next();
# 			WriteDialog(passCont);
# 		}
# 	});
# }
# function closePaper(){
# 	need("biz.dialog",function(Dialog){
# 		Dialog.hide();
# 		$("#paper_downalertImgs").attr("src","");
# 	});
# }
# //正确写入每个img 的路径
# function SetSrc(){
# 	$(".p_newhero_item").each(function(){
# 		var Surl = $(this).find("img").attr("data-src"),
# 			Links = $(this).find("ul").find("li").find("a"),
# 			LinksHref = "";
# 			Surl=Surl.replace("jpg/200","jpg/0");
# 			Surl=Surl.replace("thumb_","");
# 		$(this).find("img").attr("src",Surl);
# 		for (var i = 0; i < Links.length; i++) {
# 			LinksHref = Links.eq(i).attr("rel");
#         	LinksHref = LinksHref.replace("jpg/200","jpg/0");
#         	LinksHref = LinksHref.replace("thumb_","");
#         	//LinksHref = Links.eq(i).attr("rel");
#
#         	/*if(LinksHref.indexOf("thumb_") > 0 ){
# 				LinksHref.replace("thumb_","");
# 			}
# 			else if(LinksHref.indexOf(".jpg/200") > 0 ){
# 				LinksHref.replace(".jpg/200",".jpg/0");
# 			}*/
# 			Links.eq(i).attr("href",LinksHref);
# 		};
#
# 		$(this).click(function(){
# 			showPaper($(this));
# 		});
# 	});
# }
#
# function WorkListClearness(){
# 	amsCfg_267733.iTypeId = 2;
# 	amsCfg_267733.iListNum = 20;
# 	amsCfg_267733.sListDomId = 'Work_List_Container_267733';
# 	amsCfg_267733.callback = function(){SetSrc();};
# 	amsInit(51991,267733);
# }
#
# function WorkListOrder(iOrder){
# 	amsCfg_267733.iOrder = iOrder;
# 	amsInit(51991,267733);
# }
#
# jQuery("#SearchValue_267733").blur(function(){
# 	jQuery(".p_hd_searchbox").removeClass("p_hd_searchbox_onfocus");
# 	amsCfg_267733.SearchKey = "sProdName";
# 	amsCfg_267733.SearchValue = encodeURIComponent(jQuery("#SearchValue_267733").val());
# 	amsInit(51991,267733);
# });
# jQuery("#SearchValue_267733").focus(function(){
# 	jQuery(".p_hd_searchbox").addClass("p_hd_searchbox_onfocus");
# });
# $('.p_listmain_l').on('click', '.sProdImgDown a', function(evt){evt.preventDefault(); });
# </script>
#
# </body>
# </html>

# %%
def get_img_url(url):
    content = get_content(url)
    pattern = re.compile('sProdImgL2.*?<span>(.*?)</')
    re.findall(pattern, content)
    print(re)
get_img_url(url)
# Out:
# <module 're' from '/root/anaconda3/lib/python3.7/re.py'>

# %%
from selenium import webdriver
import time

wd = webdriver.Chrome()
wd.get("https://www.baidu.com")    # 打开百度浏览器
wd.find_element_by_id("kw").send_keys("selenium")   # 定位输入框并输入关键字
wd.find_element_by_id("su").click()   #点击[百度一下]搜索  
time.sleep(3)   #等待3秒
wd.quit()   #关闭浏览器
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'chromedriver': 'chromedriver'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-13-ad9b70f0f567> in <module>
#       2 import time
#       3
# ----> 4 wd = webdriver.Chrome()
#       5 wd.get("https://www.baidu.com")    # 打开百度浏览器
#       6 wd.find_element_by_id("kw").send_keys("selenium")   # 定位输入框并输入关键字
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home
